# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("student_performance_prediction.csv")

# %%
df.head()
# Out:
#   Student ID  Study Hours per Week  Attendance Rate  Previous Grades  \
# 0     S00001                  12.5              NaN             75.0
# 1     S00002                   9.3             95.3             60.6
# 2     S00003                  13.2              NaN             64.0
# 3     S00004                  17.6             76.8             62.4
# 4     S00005                   8.8             89.3             72.7
#
#   Participation in Extracurricular Activities Parent Education Level Passed
# 0                                         Yes                 Master    Yes
# 1                                          No            High School     No
# 2                                          No              Associate     No
# 3                                         Yes               Bachelor     No
# 4                                          No                 Master     No

# %%
df = df.drop(columns=["Student ID", 
                      "Attendance Rate", 
                      "Participation in Extracurricular Activities", 
                      "Parent Education Level"])

# %%
df.head()
# Out:
#    Study Hours per Week  Previous Grades Passed
# 0                  12.5             75.0    Yes
# 1                   9.3             60.6     No
# 2                  13.2             64.0     No
# 3                  17.6             62.4     No
# 4                   8.8             72.7     No

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 3 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Study Hours per Week  38005 non-null  float64
#  1   Previous Grades       38006 non-null  float64
#  2   Passed                38000 non-null  object
# dtypes: float64(2), object(1)
# memory usage: 937.6+ KB

# %%
import matplotlib.pyplot as plt

# %%
color_map = df['Passed'].map({'Yes': 1, 'No': 0})
plt.scatter(df['Study Hours per Week'], df['Previous Grades'], c=color_map, cmap='bwr')
plt.xlabel("Study Hours per Week")
plt.ylabel("Previous Grades")
plt.colorbar(label="Passed ")
plt.show()

# %%
x = df.iloc[:,0:2]

# %%
y = df.iloc[:,-1]

# %%
x
# Out:
#        Study Hours per Week  Previous Grades
# 0                      12.5             75.0
# 1                       9.3             60.6
# 2                      13.2             64.0
# 3                      17.6             62.4
# 4                       8.8             72.7
# ...                     ...              ...
# 39995                  15.6             51.4
# 39996                  11.3             64.2
# 39997                  13.1             38.1
# 39998                  14.1              NaN
# 39999                  11.8             68.5
#
# [40000 rows x 2 columns]

# %%
y
# Out:
# 0        Yes
# 1         No
# 2         No
# 3         No
# 4         No
#         ...
# 39995     No
# 39996    Yes
# 39997     No
# 39998     No
# 39999    Yes
# Name: Passed, Length: 40000, dtype: object

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
